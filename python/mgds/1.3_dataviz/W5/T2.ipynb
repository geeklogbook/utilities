# %%
import seaborn as sns 
import matplotlib.pyplot as plt
import pandas as pd
import plotly.graph_objects as go
from plotly.colors import n_colors
import numpy as np

# %%
dataset_comidas = pd.read_csv('../data/tips.csv')
dataset_iris = pd.read_csv('../data/iris.csv')

# %%
dataset_comidas.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dataset_iris.head(5)
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
g = sns.FacetGrid(dataset_comidas, col='time', row='smoker')
g = g.map(plt.scatter, "total_bill", "tip")

# %%
sns.pairplot(dataset_iris, hue="Name")

# %%
sns.pairplot(dataset_iris, hue="Name", palette='husl')

# %%
sns.pairplot(dataset_iris, hue="Name", palette="husl", corner=True)

# %%
sns.pairplot(dataset_iris, hue='Name', palette='husl', vars=["SepalWidth", 'SepalLength', "PetalWidth"])

# %%
sns.pairplot(dataset_iris, 
             hue="Name", 
             palette="husl", 
             x_vars=["SepalWidth", "SepalLength"], 
             y_vars=["PetalWidth", "PetalLength"])

# %%
df = pd.read_csv('../data/calories.csv')
df.head()
# Out:
#    day  calories student
# 0    1      1403       a
# 1    2      1433       a
# 2    3      1375       a
# 3    4      1385       a
# 4    5      1436       a

# %%
grid = sns.FacetGrid(data=df, col="student", hue="student", col_wrap=3)
grid.map(plt.plot, 'day', 'calories', marker="")
plt.show()

# %%
data = (np.linspace(1,2,12)[:, np.newaxis]*np.random.randn(12,200) + 
        (np.arange(12) + 2 * np.random.random(12))[:,np.newaxis])

colors = n_colors('rgb(5,200,200)', 'rgb(200,10,10)',12, colortype='rgb')

# %%
data
# Out:
# array([[ 4.28875648,  2.60373256,  0.28739367, ...,  1.58443391,
#          1.87848858,  1.36230593],
#        [ 3.37971361,  1.56080184,  2.96175986, ...,  4.03982908,
#          1.03873335,  2.19231906],
#        [ 1.59862493,  4.97635191,  2.10225483, ...,  2.3409896 ,
#          4.0311592 ,  2.98479058],
#        ...,
#        [ 8.40474701,  9.47047012,  8.9208223 , ...,  9.97487134,
#         10.42339604, 10.35320017],
#        [ 8.95410752, 10.00635523,  7.78706438, ..., 14.70261469,
#         14.62164282, 10.38012453],
#        [11.76361057, 10.30848365,  9.3478902 , ...,  6.07908692,
#         10.09924824, 13.90180065]])

# %%
colors
# Out:
# ['rgb(5.0, 200.0, 200.0)',
#  'rgb(22.727272727272727, 182.72727272727272, 182.72727272727272)',
#  'rgb(40.45454545454545, 165.45454545454544, 165.45454545454544)',
#  'rgb(58.18181818181818, 148.1818181818182, 148.1818181818182)',
#  'rgb(75.9090909090909, 130.9090909090909, 130.9090909090909)',
#  'rgb(93.63636363636363, 113.63636363636363, 113.63636363636363)',
#  'rgb(111.36363636363636, 96.36363636363636, 96.36363636363636)',
#  'rgb(129.0909090909091, 79.0909090909091, 79.0909090909091)',
#  'rgb(146.8181818181818, 61.81818181818181, 61.81818181818181)',
#  'rgb(164.54545454545453, 44.54545454545453, 44.54545454545453)',
#  'rgb(182.27272727272725, 27.272727272727252, 27.272727272727252)',
#  'rgb(200.0, 10.0, 10.0)']

# %%
print(data.shape)
# Out:
# (12, 200)

# %%
pd.DataFrame(data).head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  4.288756  2.603733  0.287394  1.214994  0.774107  0.738526  2.974718
# 1  3.379714  1.560802  2.961760  1.975277  0.824992  3.424028  2.113703
# 2  1.598625  4.976352  2.102255  2.878398  4.463690  2.761285  2.546413
# 3  3.053245  3.321617  2.191727  2.028991  2.951665  3.778576  4.787819
# 4  2.861936  6.803838  8.155355  4.660065  6.159398  6.216023  5.820899
#
#         7         8         9    ...       190       191       192       193  \
# 0  2.681383  2.025535  1.188736  ...  3.831817  2.181806  2.114180  2.083423
# 1  1.083374  3.519515  0.390955  ...  2.957498  2.667668  1.899734  3.724597
# 2  1.212826  4.212062  2.870593  ...  1.527234  3.167653  1.816863  2.380975
# 3  1.744898  2.030318  1.188211  ...  3.084956  4.230189  5.306737  2.262025
# 4  3.290641  4.987960  5.900032  ...  4.686292  5.031791  6.870672  4.875560
#
#         194       195       196       197       198       199
# 0  1.021239  1.978551  1.751829  1.584434  1.878489  1.362306
# 1  2.901699  3.374645  3.019173  4.039829  1.038733  2.192319
# 2  3.468911  4.476974  4.123240  2.340990  4.031159  2.984791
# 3  4.587459  2.644841  5.230462  2.657021  4.026793  3.844994
# 4  4.650855  6.269421  7.249898  5.705447  5.957312  5.456532
#
# [5 rows x 200 columns]

# %%
fig = go.Figure()
for data_line, color in zip(data, colors):
    fig.add_trace(go.Violin(x=data_line, line_color=color))

fig.update_traces(orientation='h', side='positive', width=3, points='outliers')
fig.update_layout(xaxis_showgrid=True, xaxis_zeroline=True)
fig.show()
