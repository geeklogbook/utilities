# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer

# %%
data = load_breast_cancer()
X = data.data
y = data.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# c:\Users\h\Documents\geeklogbook\utilities\python\mgds\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_scores = model.predict_proba(X_test)[:,1]

# %%
fpr, tpr, threshold = roc_curve(y_test, y_scores) #Calculate ROC Curve and AUC Curve
roc_auc = auc(fpr, tpr)

# %%
plt.figure()
plt.plot(fpr, tpr, color="darkorange", lw=2, label='ROC curve (area - %0.2f)' % roc_auc)
plt.plot([0,1],[0,1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.xlabel('True Positive Rate')
plt.title('ROC for Breast Cancer Dataset')
# Out:
# Text(0.5, 1.0, 'ROC for Breast Cancer Dataset')
